# %%
import os
import csv
from math import ceil

import numpy as np
from numpy.random import shuffle
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import pandas as pd

import sklearn
from sklearn.model_selection import train_test_split
from keras.models import Sequential, Model, load_model
from keras.layers import Cropping2D, Flatten, Dense, Convolution2D, Dropout, Lambda
from keras import optimizers
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
# Add which test to read. Set whether to use the right and left image in each test.
# "use_sides": True -> if use left and right cameras for traning (only when recording in center position)
records = [
    {"name": "t1-center", "use_sides": True} ,
    {"name": "t3-center-reverse", "use_sides": True} ,
    {"name": "t8-recovery", "use_sides": True} ,
    {"name": "t9-hard-recovery", "use_sides": True} ,
    {"name": "t10-recovery-normal-lines", "use_sides": True} ,
    {"name": "data_udacity", "use_sides": True}
]

# Read CSVs
samples_array = [[],[]]
data_len = 0
for record in records:
    with open('./data/'+record["name"]+'/driving_log.csv') as csvfile:
        reader = csv.reader(csvfile)
        for line in reader:
            center_img = line[0]
            steering = float(line[3])
            samples_array[0].append(center_img)
            samples_array[1].append(steering)
            
            if record["use_sides"]:
                correction = 0.25
                steering_left = steering + correction
                steering_right = steering - correction
                    
                left_img = line[1]
                samples_array[0].append(left_img)
                samples_array[1].append(steering_left)
                
                right_img = line[2]
                samples_array[0].append(right_img)
                samples_array[1].append(steering_right)
                
    new_len = len(samples_array[0])-data_len
    data_len += new_len
    print("added "+str(new_len)+" dates from: "+record["name"])
        
samples_array = np.array(samples_array).T
print("total data = "+str(len(samples_array)))
# Out:
# added 4896 dates from: t1-center
# added 6546 dates from: t3-center-reverse
# added 3594 dates from: t8-recovery
# added 1800 dates from: t9-hard-recovery
# added 1983 dates from: t10-recovery-normal-lines
# added 24108 dates from: data_udacity
# total data = 42927

# %%
# %matplotlib inline
steering = samples_array[:,1].astype(np.float)
n, bins, p = plt.hist(steering, bins=100)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# Crop high peaks of histogram
bins_cropped = 3

n = np.array(n)
crop_index = n.argsort()[-bins_cropped:]
crop_index = np.flip(crop_index)

remove_indx = []
for i in range(bins_cropped):
    indx_delete = crop_index[i]
    new_bean_values = (n[indx_delete+1]+n[indx_delete-1])/2 # mean of neighbors beans. This will be the new value of cropped bean
    nro_delete = np.int(n[crop_index[i]]-new_bean_values) # amount to delete
    
    indx = np.where((bins[indx_delete]<=steering) & (steering<bins[indx_delete+1]))
    indx = np.ravel(indx)
    np.random.shuffle(indx)
    remove_indx.extend(indx[0:nro_delete])

samples_array_balanced = []
for i , s in enumerate(samples_array):
    if i not in remove_indx:
        samples_array_balanced.append(s)
# Out:
# C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if sys.path[0] == '':

# %%
# %matplotlib inline
steering = np.array(samples_array_balanced)[:,1].astype(np.float)
sns.displot(steering,bins=100)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# #### Nvidia End to End Learning for Self-Driving Cars
# Paper: https://images.nvidia.com/content/tegra/automotive/images/2016/solutions/pdf/end-to-end-dl-using-px.pdf
# <img src="nvidia-net.png" alt="NvidiaE2ENet" style="width: 400px;"/>

# %%
def get_model():
    ch, row, col = 3, 80, 320  # Trimmed image format
    ch, row, col = 3, 80, 320  # Trimmed image format

    # Model: Nvidia End to End Learning for Self-Driving Cars
    model = Sequential()
    
    # Preprocess incoming data, crop interest zone
    model.add(Cropping2D(cropping=((60,20), (0,0)), input_shape=(160,320,3)))
    # Preprocess incoming data, centered around zero with small standard deviation 
    model.add(Lambda(lambda x: x/127.5 - 1.))

    model.add(Convolution2D(24, (5, 5), strides=(2, 2), activation='relu'))
    model.add(Convolution2D(36, (5, 5), strides=(2, 2), activation='relu'))
    model.add(Convolution2D(48, (5, 5), strides=(2, 2), activation='relu'))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(Flatten())
    model.add(Dense(100))
    model.add(Dropout(0.5))
    model.add(Dense(50))
    model.add(Dropout(0.5))
    model.add(Dense(10))
    model.add(Dense(1))
    
    return model

# %%
def change_contrast(img):
    hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    scale = np.random.uniform(.6, 1.2)
    hsv[:, :, 2] = hsv[:, :, 2] * scale
    return cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)

def generator(samples_array, batch_size=32, traning_mode = False):
    num_samples = len(samples_array[0])
    while 1: # Loop forever so the generator never terminates
        shuffle(samples_array)
        for offset in range(0, num_samples, batch_size):
            batch_samples = samples_array[offset:offset+batch_size]
            images = []
            angles = []
            for batch_sample in batch_samples:
                file_name = batch_sample[0].split("\\")[-1]
                test_name = batch_sample[0].split("\\")[-3]
                name = './data/'+test_name+'/IMG/'+batch_sample[0].split("\\")[-1]
                img = cv2.imread(name)
                ang = float(batch_sample[1])
                
                # Generate random flipped images
                # Only for training (we should not augment validation data)
                if(traning_mode):
                    if np.random.rand() < 0.5:
                        img = np.fliplr(img)
                        ang = -ang
                    # Change contrast randomly
                    if np.random.rand() < 0.5:                    
                        img = change_contrast(img)
                
                images.append(img)
                angles.append(ang)

            # Trim image to only see section with road
            X_train = np.array(images)
            y_train = np.array(angles)
            yield sklearn.utils.shuffle(X_train, y_train)

# %%
# Set our batch size
batch_size=256

# Split in train/validation
shuffle(samples_array_balanced)
train_samples, validation_samples = train_test_split(samples_array_balanced, test_size=0.3)

# compile and train the model using the generator function
train_generator = generator(train_samples, batch_size=batch_size, traning_mode  = True)
validation_generator = generator(validation_samples, batch_size=batch_size, traning_mode  = False)

# model = get_model()
model = load_model('./weights.best.hdf5') # use previous test to continue traning

optimizer = optimizers.Adam(lr=0.0001)
model.compile(loss='mse', optimizer=optimizer)

# checkpoints_filepath="./checkpoints/weights-improvement-{epoch:02d}.hdf5"
checkpoints_filepath="./weights.best.hdf5"
checkpoint = ModelCheckpoint(checkpoints_filepath, monitor='val_loss', 
                             verbose=1, save_best_only=True, mode='min')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0)
# callbacks_list = [checkpoint,es]
callbacks_list = [checkpoint]

history_object = model.fit_generator(train_generator,
            steps_per_epoch=ceil(len(train_samples)/batch_size),
            validation_data=validation_generator,
            validation_steps=ceil(len(validation_samples)/batch_size),
            epochs=100, callbacks=callbacks_list, verbose=1)

model.save('model.h5')
# Out:
# Epoch 1/100
# 77/77 [==============================] - 94s 1s/step - loss: 0.0131 - val_loss: 0.0102
#
# Epoch 00001: val_loss improved from inf to 0.01024, saving model to ./weights.best.hdf5
# Epoch 2/100
# 77/77 [==============================] - 92s 1s/step - loss: 0.0121 - val_loss: 0.0098
#
# Epoch 00002: val_loss improved from 0.01024 to 0.00981, saving model to ./weights.best.hdf5
# Epoch 3/100
# 77/77 [==============================] - 92s 1s/step - loss: 0.0119 - val_loss: 0.0083
#
# Epoch 00003: val_loss improved from 0.00981 to 0.00832, saving model to ./weights.best.hdf5
# Epoch 4/100
# 77/77 [==============================] - 93s 1s/step - loss: 0.0117 - val_loss: 0.0093
#
# Epoch 00004: val_loss did not improve from 0.00832
# Epoch 5/100
# 77/77 [==============================] - 92s 1s/step - loss: 0.0118 - val_loss: 0.0107
#
# Epoch 00005: val_loss did not improve from 0.00832
# Epoch 6/100
# 77/77 [==============================] - 93s 1s/step - loss: 0.0115 - val_loss: 0.0082
#
# Epoch 00006: val_loss improved from 0.00832 to 0.00817, saving model to ./weights.best.hdf5
# Epoch 7/100
# 77/77 [==============================] - 93s 1s/step - loss: 0.0110 - val_loss: 0.0094
#
# Epoch 00007: val_loss did not improve from 0.00817
# Epoch 8/100
# 77/77 [==============================] - 92s 1s/step - loss: 0.0111 - val_loss: 0.0103
#
# Epoch 00008: val_loss did not improve from 0.00817
# Epoch 9/100
# 77/77 [==============================] - 92s 1s/step - loss: 0.0108 - val_loss: 0.0087
#
# Epoch 00009: val_loss did not improve from 0.00817
# Epoch 10/100
# 77/77 [==============================] - 92s 1s/step - loss: 0.0109 - val_loss: 0.0099
#
# Epoch 00010: val_loss did not improve from 0.00817
# Epoch 11/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.0104 - val_loss: 0.0123
#
# Epoch 00011: val_loss did not improve from 0.00817
# Epoch 12/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0104 - val_loss: 0.0094
#
# Epoch 00012: val_loss did not improve from 0.00817
# Epoch 13/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0104 - val_loss: 0.0113
#
# Epoch 00013: val_loss did not improve from 0.00817
# Epoch 14/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.0105 - val_loss: 0.0096
#
# Epoch 00014: val_loss did not improve from 0.00817
# Epoch 15/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0105 - val_loss: 0.0114
#
# Epoch 00015: val_loss did not improve from 0.00817
# Epoch 16/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0102 - val_loss: 0.0120
#
# Epoch 00016: val_loss did not improve from 0.00817
# Epoch 17/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0102 - val_loss: 0.0122
#
# Epoch 00017: val_loss did not improve from 0.00817
# Epoch 18/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0097 - val_loss: 0.0103
#
# Epoch 00018: val_loss did not improve from 0.00817
# Epoch 19/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.0097 - val_loss: 0.0097
#
# Epoch 00019: val_loss did not improve from 0.00817
# Epoch 20/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0095 - val_loss: 0.0122
#
# Epoch 00020: val_loss did not improve from 0.00817
# Epoch 21/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0098 - val_loss: 0.0090
#
# Epoch 00021: val_loss did not improve from 0.00817
# Epoch 22/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0095 - val_loss: 0.0119
#
# Epoch 00022: val_loss did not improve from 0.00817
# Epoch 23/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0092 - val_loss: 0.0109
#
# Epoch 00023: val_loss did not improve from 0.00817
# Epoch 24/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0095 - val_loss: 0.0095
#
# Epoch 00024: val_loss did not improve from 0.00817
# Epoch 25/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0092 - val_loss: 0.0101
#
# Epoch 00025: val_loss did not improve from 0.00817
# Epoch 26/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0092 - val_loss: 0.0093
#
# Epoch 00026: val_loss did not improve from 0.00817
# Epoch 27/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0088 - val_loss: 0.0100
#
# Epoch 00027: val_loss did not improve from 0.00817
# Epoch 28/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0088 - val_loss: 0.0102
#
# Epoch 00028: val_loss did not improve from 0.00817
# Epoch 29/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0086 - val_loss: 0.0088
#
# Epoch 00029: val_loss did not improve from 0.00817
# Epoch 30/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.0086 - val_loss: 0.0139
#
# Epoch 00030: val_loss did not improve from 0.00817
# Epoch 31/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0088 - val_loss: 0.0101
#
# Epoch 00031: val_loss did not improve from 0.00817
# Epoch 32/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.0086 - val_loss: 0.0090
#
# Epoch 00032: val_loss did not improve from 0.00817
# Epoch 33/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0088 - val_loss: 0.0093
#
# Epoch 00033: val_loss did not improve from 0.00817
# Epoch 34/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0083 - val_loss: 0.0098
#
# Epoch 00034: val_loss did not improve from 0.00817
# Epoch 35/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0084 - val_loss: 0.0134
#
# Epoch 00035: val_loss did not improve from 0.00817
# Epoch 36/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0081 - val_loss: 0.0092
#
# Epoch 00036: val_loss did not improve from 0.00817
# Epoch 37/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0084 - val_loss: 0.0118
#
# Epoch 00037: val_loss did not improve from 0.00817
# Epoch 38/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0081 - val_loss: 0.0095
#
# Epoch 00038: val_loss did not improve from 0.00817
# Epoch 39/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0083 - val_loss: 0.0107
#
# Epoch 00039: val_loss did not improve from 0.00817
# Epoch 40/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0079 - val_loss: 0.0117
#
# Epoch 00040: val_loss did not improve from 0.00817
# Epoch 41/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0083 - val_loss: 0.0086
#
# Epoch 00041: val_loss did not improve from 0.00817
# Epoch 42/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0078 - val_loss: 0.0110
#
# Epoch 00042: val_loss did not improve from 0.00817
# Epoch 43/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0078 - val_loss: 0.0107
#
# Epoch 00043: val_loss did not improve from 0.00817
# Epoch 44/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0075 - val_loss: 0.0110
#
# Epoch 00044: val_loss did not improve from 0.00817
# Epoch 45/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0078 - val_loss: 0.0121
#
# Epoch 00045: val_loss did not improve from 0.00817
# Epoch 46/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0078 - val_loss: 0.0109
#
# Epoch 00046: val_loss did not improve from 0.00817
# Epoch 47/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0076 - val_loss: 0.0120
#
# Epoch 00047: val_loss did not improve from 0.00817
# Epoch 48/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0077 - val_loss: 0.0134
#
# Epoch 00048: val_loss did not improve from 0.00817
# Epoch 49/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0077 - val_loss: 0.0085
#
# Epoch 00049: val_loss did not improve from 0.00817
# Epoch 50/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0073 - val_loss: 0.0145
#
# Epoch 00050: val_loss did not improve from 0.00817
# Epoch 51/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0075 - val_loss: 0.0133
#
# Epoch 00051: val_loss did not improve from 0.00817
# Epoch 52/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0075 - val_loss: 0.0107
#
# Epoch 00052: val_loss did not improve from 0.00817
# Epoch 53/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0076 - val_loss: 0.0109
#
# Epoch 00053: val_loss did not improve from 0.00817
# Epoch 54/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0072 - val_loss: 0.0102
#
# Epoch 00054: val_loss did not improve from 0.00817
# Epoch 55/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.0072 - val_loss: 0.0122
#
# Epoch 00055: val_loss did not improve from 0.00817
# Epoch 56/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0071 - val_loss: 0.0159
#
# Epoch 00056: val_loss did not improve from 0.00817
# Epoch 57/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0071 - val_loss: 0.0115
#
# Epoch 00057: val_loss did not improve from 0.00817
# Epoch 58/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0069 - val_loss: 0.0134
#
# Epoch 00058: val_loss did not improve from 0.00817
# Epoch 59/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0073 - val_loss: 0.0151
#
# Epoch 00059: val_loss did not improve from 0.00817
# Epoch 60/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0071 - val_loss: 0.0107
#
# Epoch 00060: val_loss did not improve from 0.00817
# Epoch 61/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0073 - val_loss: 0.0139
#
# Epoch 00061: val_loss did not improve from 0.00817
# Epoch 62/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0069 - val_loss: 0.0149
#
# Epoch 00062: val_loss did not improve from 0.00817
# Epoch 63/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0069 - val_loss: 0.0131
#
# Epoch 00063: val_loss did not improve from 0.00817
# Epoch 64/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0066 - val_loss: 0.0178
#
# Epoch 00064: val_loss did not improve from 0.00817
# Epoch 65/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0069 - val_loss: 0.0116
#
# Epoch 00065: val_loss did not improve from 0.00817
# Epoch 66/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0068 - val_loss: 0.0179
#
# Epoch 00066: val_loss did not improve from 0.00817
# Epoch 67/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0069 - val_loss: 0.0102
#
# Epoch 00067: val_loss did not improve from 0.00817
# Epoch 68/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0068 - val_loss: 0.0102
#
# Epoch 00068: val_loss did not improve from 0.00817
# Epoch 69/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0068 - val_loss: 0.0105
#
# Epoch 00069: val_loss did not improve from 0.00817
# Epoch 70/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0068 - val_loss: 0.0151
#
# Epoch 00070: val_loss did not improve from 0.00817
# Epoch 71/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0068 - val_loss: 0.0129
#
# Epoch 00071: val_loss did not improve from 0.00817
# Epoch 72/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0067 - val_loss: 0.0144
#
# Epoch 00072: val_loss did not improve from 0.00817
# Epoch 73/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0065 - val_loss: 0.0120
#
# Epoch 00073: val_loss did not improve from 0.00817
# Epoch 74/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0067 - val_loss: 0.0115
#
# Epoch 00074: val_loss did not improve from 0.00817
# Epoch 75/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0065 - val_loss: 0.0119
#
# Epoch 00075: val_loss did not improve from 0.00817
# Epoch 76/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0064 - val_loss: 0.0133
#
# Epoch 00076: val_loss did not improve from 0.00817
# Epoch 77/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0065 - val_loss: 0.0119
#
# Epoch 00077: val_loss did not improve from 0.00817
# Epoch 78/100
# 77/77 [==============================] - 93s 1s/step - loss: 0.0067 - val_loss: 0.0147
#
# Epoch 00078: val_loss did not improve from 0.00817
# Epoch 79/100
# 77/77 [==============================] - 92s 1s/step - loss: 0.0064 - val_loss: 0.0146
#
# Epoch 00079: val_loss did not improve from 0.00817
# Epoch 80/100
# 77/77 [==============================] - 92s 1s/step - loss: 0.0064 - val_loss: 0.0130
#
# Epoch 00080: val_loss did not improve from 0.00817
# Epoch 81/100
# 77/77 [==============================] - 92s 1s/step - loss: 0.0062 - val_loss: 0.0103
#
# Epoch 00081: val_loss did not improve from 0.00817
# Epoch 82/100
# 77/77 [==============================] - 92s 1s/step - loss: 0.0064 - val_loss: 0.0111
#
# Epoch 00082: val_loss did not improve from 0.00817
# Epoch 83/100
# 77/77 [==============================] - 94s 1s/step - loss: 0.0065 - val_loss: 0.0105
#
# Epoch 00083: val_loss did not improve from 0.00817
# Epoch 84/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.0064 - val_loss: 0.0139
#
# Epoch 00084: val_loss did not improve from 0.00817
# Epoch 85/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0062 - val_loss: 0.0131
#
# Epoch 00085: val_loss did not improve from 0.00817
# Epoch 86/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0061 - val_loss: 0.0110
#
# Epoch 00086: val_loss did not improve from 0.00817
# Epoch 87/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.0062 - val_loss: 0.0100
#
# Epoch 00087: val_loss did not improve from 0.00817
# Epoch 88/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0062 - val_loss: 0.0111
#
# Epoch 00088: val_loss did not improve from 0.00817
# Epoch 89/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0060 - val_loss: 0.0114
#
# Epoch 00089: val_loss did not improve from 0.00817
# Epoch 90/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0062 - val_loss: 0.0120
#
# Epoch 00090: val_loss did not improve from 0.00817
# Epoch 91/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0059 - val_loss: 0.0121
#
# Epoch 00091: val_loss did not improve from 0.00817
# Epoch 92/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0063 - val_loss: 0.0116
#
# Epoch 00092: val_loss did not improve from 0.00817
# Epoch 93/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0060 - val_loss: 0.0115
#
# Epoch 00093: val_loss did not improve from 0.00817
# Epoch 94/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0061 - val_loss: 0.0115
#
# Epoch 00094: val_loss did not improve from 0.00817
# Epoch 95/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.0061 - val_loss: 0.0223
#
# Epoch 00095: val_loss did not improve from 0.00817
# Epoch 96/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0059 - val_loss: 0.0150
#
# Epoch 00096: val_loss did not improve from 0.00817
# Epoch 97/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0059 - val_loss: 0.0125
#
# Epoch 00097: val_loss did not improve from 0.00817
# Epoch 98/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0057 - val_loss: 0.0108
#
# Epoch 00098: val_loss did not improve from 0.00817
# Epoch 99/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0061 - val_loss: 0.0120
#
# Epoch 00099: val_loss did not improve from 0.00817
# Epoch 100/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0061 - val_loss: 0.0141
#
# Epoch 00100: val_loss did not improve from 0.00817

# %%
### print the keys contained in the history object
print(history_object.history.keys())

### plot the training and validation loss for each epoch
plt.plot(history_object.history['loss'])
plt.plot(history_object.history['val_loss'])
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# dict_keys(['val_loss', 'loss'])
